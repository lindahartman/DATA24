# %% [markdown]
# ---
# title: Data analysis with Python
# subtitle: Making Jupyter Notebook cool again
# date: '2024-12-12'
# author:
#   - name: Josiah Carberry
#     id: jc
#     orcid: 0000-0002-1825-0097
#     email: josiah@psychoceramics.org
#     affiliation:
#       - name: Brown University
#         city: Providence
#         state: RI
#         url: www.brown.edu
#   - name: Helen Bentley
#     id: hb
#     orcid: 0000-0004-2304-3456
#     email: helen@microdevices.co.uk
#     affiliation:
#       - name: Microdevices PLC
#         city: Oxford
#         country: UK
#         url: www.microdevices.co.uk
# abstract: >
#   The characteristic theme of the works of Stone is
#   the bridge between culture and society. ...
# keywords:
#   - Metaphysics
#   - String Theory
# license: "CC BY"
# copyright:
#   holder: Josiah Carberry
#   year: 2024
# citation:
#   container-title: Journal of Psychoceramics
#   volume: 1
#   issue: 1
#   doi: 10.5555/12345678
# funding: "The authors received no specific funding for this work."
# format:
#   html:
#     theme: flatly
#     embed-resources: true
#     title-block-banner: true
# ---

# %% [markdown]
# ## Introduction

# %% [markdown]
# :::{.callout-note}
# This is a callout. Not sure if it will show properly
# :::

# %%
import polars as pl
from plotnine import *
from gapminder import gapminder

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# Some text should go here

# %% [markdown]
# :::{.callout-warning}
# Pay attention that the next cell is here only to create two columns. It opens a DIV which needs to be closed later
# :::

# %% [markdown]
# ::::{.columns}
# :::{.column width="50%"}

# %%
#| label: fig-gapmin
#| fig-cap: "my caption"
#| echo: false
(
ggplot(gapminder)+
geom_point(mapping=aes(x='gdpPercap', y='lifeExp', color='continent'))
)

# %% [markdown]
# :::
# :::{.column width="50%"}

# %%
#| label: fig-gapmin-bw
#| fig-cap: Another chart about the same thing
#| echo: false
(
ggplot(gapminder)+
geom_point(mapping=aes(x='gdpPercap', y='lifeExp', color='continent'))
)

# %% [markdown]
# :::
# ::::

# %% [markdown]
# Here in @fig-gapmin we can see that life is hard in Asia. Most of the other research, like the one in @fig-gapmin-bw, agree

# %% [markdown]
# This is a markdown cell where you can write your comments
